# %%
import pandas as pd

# %%
#series is one dimensional array
data=pd.Series([1,2,3,4,5])
data
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# can change the index value
data=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
# Data Frame : 2 Dimensional Array

data=pd.DataFrame([1,2,3,4,5])
data
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
lst=[[1,2,3],[3,5,6],[8,5,3]]
df=pd.DataFrame(lst)
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  3  5  6
# 2  8  5  3

# %%
#Dictionary

dict={'Name':["kamal","Amal","Nimal","Sunimal"],"Marks":[89,45,56,75]}
df=pd.DataFrame(dict)
df
# Out:
#       Name  Marks
# 0    kamal     89
# 1     Amal     45
# 2    Nimal     56
# 3  Sunimal     75

# %%
# How to add 2 data frame

dict_1={"sunil":[89,45,56,75],"Amal":[45,65,56,95]}
dict_2={"kamal":[49,55,66,25],"Nimal":[49,35,86,75]}
df_1=pd.DataFrame(dict_1)
df_2=pd.DataFrame(dict_2)

# %%
df_1
# Out:
#    sunil  Amal
# 0     89    45
# 1     45    65
# 2     56    56
# 3     75    95

# %%
df_2
# Out:
#    kamal  Nimal
# 0     49     49
# 1     55     35
# 2     66     86
# 3     25     75

# %%
pd.concat([df_1,df_2]) #axis=0 default
# Out:
#    sunil  Amal  kamal  Nimal
# 0   89.0  45.0    NaN    NaN
# 1   45.0  65.0    NaN    NaN
# 2   56.0  56.0    NaN    NaN
# 3   75.0  95.0    NaN    NaN
# 0    NaN   NaN   49.0   49.0
# 1    NaN   NaN   55.0   35.0
# 2    NaN   NaN   66.0   86.0
# 3    NaN   NaN   25.0   75.0

# %%
pd.concat([df_1,df_2],axis=1)
# Out:
#    sunil  Amal  kamal  Nimal
# 0     89    45     49     49
# 1     45    65     55     35
# 2     56    56     66     86
# 3     75    95     25     75

# %%
data=pd.read_csv("weather.csv")
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
# Another location
# add "r" infront of the path

data=pd.read_csv(r"C:\Users\Isuru sandaruwan\Desktop\python\weather.csv")
data
# Out:
#        Data.Precipitation   Date.Full  Date.Month  Date.Week of  Date.Year  \
# 0                    0.00  2016-01-03           1             3       2016
# 1                    0.00  2016-01-03           1             3       2016
# 2                    0.16  2016-01-03           1             3       2016
# 3                    0.00  2016-01-03           1             3       2016
# 4                    0.01  2016-01-03           1             3       2016
# ...                   ...         ...         ...           ...        ...
# 16738                0.08  2017-01-01           1             1       2017
# 16739                0.00  2017-01-01           1             1       2017
# 16740                0.00  2017-01-01           1             1       2017
# 16741                0.06  2017-01-01           1             1       2017
# 16742                0.10  2017-01-01           1             1       2017
#
#       Station.City Station.Code Station.Location Station.State  \
# ...

# %%
#to check the shape
data.shape # return the row and column
# Out:
# (16743, 14)

# %%
## delete unnessory data
del data['Data.Precipitation']

# %%
data
# Out:
#         Date.Full  Date.Month  Date.Week of  Date.Year Station.City  \
# 0      2016-01-03           1             3       2016   Birmingham
# 1      2016-01-03           1             3       2016   Huntsville
# 2      2016-01-03           1             3       2016       Mobile
# 3      2016-01-03           1             3       2016   Montgomery
# 4      2016-01-03           1             3       2016    Anchorage
# ...           ...         ...           ...        ...          ...
# 16738  2017-01-01           1             1       2017       Casper
# 16739  2017-01-01           1             1       2017     Cheyenne
# 16740  2017-01-01           1             1       2017       Lander
# 16741  2017-01-01           1             1       2017      Rawlins
# 16742  2017-01-01           1             1       2017     Sheridan
#
#       Station.Code Station.Location Station.State  Data.Temperature.Avg Temp  \
# ...

# %%
#another method for delete column
data=data.drop(columns=['Date.Week of'])
data
# Out:
#         Date.Full  Date.Month  Date.Year Station.City Station.Code  \
# 0      2016-01-03           1       2016   Birmingham          BHM
# 1      2016-01-03           1       2016   Huntsville          HSV
# 2      2016-01-03           1       2016       Mobile          MOB
# 3      2016-01-03           1       2016   Montgomery          MGM
# 4      2016-01-03           1       2016    Anchorage          ANC
# ...           ...         ...        ...          ...          ...
# 16738  2017-01-01           1       2017       Casper          CPR
# 16739  2017-01-01           1       2017     Cheyenne          CYS
# 16740  2017-01-01           1       2017       Lander          LND
# 16741  2017-01-01           1       2017      Rawlins          RWL
# 16742  2017-01-01           1       2017     Sheridan          SHR
#
#       Station.Location Station.State  Data.Temperature.Avg Temp  \
# 0       Birmingham, AL       Alabama                         39
# ...

# %%
# Get specific columns
data=data[["Data.Temperature.Avg Temp","Data.Temperature.Max Temp"]]

data
# Out:
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# 0                             39                         46
# 1                             39                         47
# 2                             46                         51
# 3                             45                         52
# 4                             34                         38
# ...                          ...                        ...
# 16738                         23                         32
# 16739                         32                         42
# 16740                         17                         29
# 16741                         23                         31
# 16742                         21                         34
#
# [16743 rows x 2 columns]

# %%
# To check data count
data.count()
# Out:
# Data.Temperature.Avg Temp    16743
# Data.Temperature.Max Temp    16743
# dtype: int64

# %%
#to print data
data.head()
# Out:
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# 0                         39                         46
# 1                         39                         47
# 2                         46                         51
# 3                         45                         52
# 4                         34                         38

# %%
#to print data
data.head(10)
# Out:
#    Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# 0                         39                         46
# 1                         39                         47
# 2                         46                         51
# 3                         45                         52
# 4                         34                         38
# 5                         38                         44
# 6                         30                         36
# 7                         22                         32
# 8                         34                         36
# 9                         38                         43

# %%
# Null Value replace with mean value
data.column_name=data.column_name.fillna(data.column_name.mean())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2372\483447301.py in <module>
#       1 # Null Value replace with mean value
# ----> 2 data.column_name=data.column_name.fillna(data.column_name.mean())
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'column_name'

# %%
# filter value
data['Data.Temperature.Max Temp']>40
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 16738    False
# 16739     True
# 16740    False
# 16741    False
# 16742    False
# Name: Data.Temperature.Max Temp, Length: 16743, dtype: bool

# %%
condition=data['Data.Temperature.Max Temp']>40
filter=data[condition]
filter
# Out:
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# 0                             39                         46
# 1                             39                         47
# 2                             46                         51
# 3                             45                         52
# 5                             38                         44
# ...                          ...                        ...
# 16730                         38                         46
# 16731                         44                         53
# 16732                         38                         49
# 16733                         44                         53
# 16739                         32                         42
#
# [14746 rows x 2 columns]

# %%
condition=data['Data.Temperature.Max Temp']>40
filter=data[condition]
filter['Data.Temperature.Avg Temp']
# Out:
# 0        39
# 1        39
# 2        46
# 3        45
# 5        38
#          ..
# 16730    38
# 16731    44
# 16732    38
# 16733    44
# 16739    32
# Name: Data.Temperature.Avg Temp, Length: 14746, dtype: int64

# %%
## Multiple condition

condition=(data['Data.Temperature.Max Temp']>40) & (data['Data.Temperature.Avg Temp']>40) 
filter=data[condition]
filter
# Out:
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# 2                             46                         51
# 3                             45                         52
# 25                            60                         60
# 26                            60                         60
# 27                            60                         60
# ...                          ...                        ...
# 16720                         42                         50
# 16721                         44                         52
# 16722                         44                         52
# 16731                         44                         53
# 16733                         44                         53
#
# [13259 rows x 2 columns]

# %%
# Data description
data.describe()
# Out:
#        Data.Temperature.Avg Temp  Data.Temperature.Max Temp
# count               16743.000000               16743.000000
# mean                   56.089112                  66.042406
# std                    18.798295                  19.787954
# min                   -27.000000                 -19.000000
# 25%                    44.000000                  53.000000
# 50%                    58.000000                  68.000000
# 75%                    71.000000                  82.000000
# max                   100.000000                 111.000000

# %%
from matplotlib import pyplot as plt

x=range(16743) # data count=16743
y1=data['Data.Temperature.Avg Temp']
y2=data['Data.Temperature.Max Temp']
plt.plot(x,y1)
plt.plot(x,y2)

# %%
x=range(20) # data count=16743
y1=data['Data.Temperature.Avg Temp'][:20]
y2=data['Data.Temperature.Max Temp'][:20]
plt.plot(x,y1)
plt.plot(x,y2)
